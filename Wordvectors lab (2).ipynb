# %% [markdown]
# Part 1: Genism

# %% [markdown]
# In this lab, I'll be working with "Sophie's World," a philosophical book that explores the history of philosophy. This book holds a special place in my heart. It's one of my all-time favorite books. I initially read it in French as a teenager and have now decided to revisit it, this time in English. I'm curious to explore some word vector analysis on its text.

# %%
import re
import nltk
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random

from gensim.models import Word2Vec

from sklearn.decomposition import IncrementalPCA
from sklearn.manifold import TSNE

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dani\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# read a file you have stored locally
# I added the Hunger Games for simplicity
file = open("Sophies world.txt", 'r', encoding='utf-8').read()

# first, remove unwanted new line and tab characters from the text
for char in ["\n", "\r", "\d", "\t"]:
   file = file.replace(char, " ")

# check
print(file[:100])
# Out:
# Sophie’s World   Jostien Gaarder     Reviews:  More praise for the international bestseller that has

# %%
# this is simplified for demonstration
def sample_clean_text(text: str):
    # step 1: tokenize the text into sentences
    sentences = nltk.sent_tokenize(text)

    # step 2: tokenize each sentence into words
    tokenized_sentences = [nltk.word_tokenize(sent) for sent in sentences]

    # step 3: convert each word to lowercase
    tokenized_text = [[word.lower() for word in sent] for sent in tokenized_sentences]
    
    # return your tokens
    return tokenized_text

# call the function
tokens = sample_clean_text(text = file)

# check
print(tokens[:10])
# Out:
# [['sophie', '’', 's', 'world', 'jostien', 'gaarder', 'reviews', ':', 'more', 'praise', 'for', 'the', 'international', 'bestseller', 'that', 'has', 'become', '“', 'europe', '’', 's', 'oddball', 'literary', 'sensation', 'of', 'the', 'decade', '”', '(', 'new', 'york', 'newsday', ')', '“', 'a', 'page-turner.', '”', '—entertainment', 'weekly', '“', 'first', ',', 'think', 'of', 'a', 'beginner', '’', 's', 'guide', 'to', 'philosophy', ',', 'written', 'by', 'a', 'schoolteacher', '...', 'next', ',', 'imagine', 'a', 'fantasy', 'novel—', 'something', 'like', 'a', 'modern-day', 'version', 'of', 'through', 'the', 'looking', 'glass', '.'], ['meld', 'these', 'disparate', 'genres', ',', 'and', 'what', 'do', 'you', 'get', '?'], ['well', ',', 'what', 'you', 'get', 'is', 'an', 'improbable', 'international', 'bestseller', '...', 'a', 'runaway', 'hit', '...', '[', 'a', ']', 'tour', 'deforce.', '”', '—time', '“', 'compelling.', '”', '—los', 'angeles', 'times', '“', 'its', 'depth', 'of', 'learning', ',', 'its', 'intelligence', 'and', 'its', 'totally', 'original', 'conception', 'give', 'it', 'enormous', 'magnetic', 'appeal', '...', 'to', 'be', 'fully', 'human', ',', 'and', 'to', 'feel', 'our', 'continuity', 'with', '3,000', 'years', 'of', 'philosophical', 'inquiry', ',', 'we', 'need', 'to', 'put', 'ourselves', 'in', 'sophie', '’', 's', 'world.', '”', '—boston', 'sunday', 'globe', '“', 'involving', 'and', 'often', 'humorous.', '”', '—usa', 'today', '“', 'in', 'the', 'adroit', 'hands', 'of', 'jostein', 'gaarder', ',', 'the', 'whole', 'sweep', 'of', 'three', 'millennia', 'of', 'western', 'philosophy', 'is', 'rendered', 'as', 'lively', 'as', 'a', 'gossip', 'column', '...'], ['literary', 'sorcery', 'of', 'the', 'first', 'rank.', '”', '—fort', 'worth', 'star-', 'telegram', '“', 'a', 'comprehensive', 'history', 'of', 'western', 'philosophy', 'as', 'recounted', 'to', 'a', '14-year-old', 'norwegian', 'schoolgirl', '...'], ['the', 'book', 'will', 'serve', 'as', 'a', 'first-rate', 'introduction', 'to', 'anyone', 'who', 'never', 'took', 'an', 'introductory', 'philosophy', 'course', ',', 'and', 'as', 'a', 'pleasant', 'refresher', 'for', 'those', 'who', 'have', 'and', 'have', 'forgotten', 'most', 'of', 'it', '...', '[', 'sophie', '’', 's', 'mother', ']', 'is', 'a', 'marvelous', 'comic', 'foil.', '”', '—newsweek', '“', 'terrifically', 'entertaining', 'and', 'imaginative', '...', 'i', '’', 'll', 'read', 'sophie', '’', 's', 'world', 'again.', '”', '—daily', 'mail', '“', 'what', 'is', 'admirable', 'in', 'the', 'novel', 'is', 'the', 'utter', 'unpretentious-ness', 'of', 'the', 'philosophical', 'lessons', ',', 'the', 'plain', 'and', 'workmanlike', 'prose', 'which', 'manages', 'to', 'deliver', 'western', 'philosophy', 'in', 'accounts', 'that', 'are', 'crystal', 'clear', '.'], ['it', 'is', 'heartening', 'to', 'know', 'that', 'a', 'book', 'subtitled', '“', '’', 'a', 'novel', 'about', 'the', 'history', 'of', 'philosophy', '’', 'was', 'not', 'only', 'a', 'bestseller', 'in', 'france', ',', 'but', 'for', 'a', 'while', 'europe', '’', 's', 'hottest', 'novel.', '”', '—the', 'washington', 'post', 'book', 'world', '“', 'a', 'rare', 'bird', 'indeed', ',', 'a', 'short', 'history', 'of', 'western', 'philosophical', 'thought', 'from', 'socrates', 'to', 'sartre', ',', 'coyly', 'embedded', 'in', 'the', 'wrapping', 'of', 'a', 'suspense', 'novel.', '”', '—new', 'york', 'newsday', '“', 'a', 'simply', 'wonderful', ',', 'irresistible', 'book', '...', 'a', 'cross', 'between', 'bertrand', 'russell', '’', 's', 'history', 'of', 'western', 'philosophy', 'and', 'alice', 'in', 'wonderland.', '”', '—the', 'daily', 'telegraph', '“', 'an', 'exciting', 'trek', 'into', ',', 'the', 'realm', 'of', 'thought', ',', 'from', 'the', 'ancient', 'philosophers', '’', 'school', 'of', 'athens', 'to', 'the', 'konigsberg', 'of', 'kant', '...', 'and', 'a', 'brilliant', 'success.', '”', '-der', 'spiegel', '“', 'intelligently', 'written', '...', 'an', 'enchanting', 'way', 'to', 'learn', 'philosophy.', '”', '—baton', 'rouge ...

# %%
model = Word2Vec(tokens,vector_size=100)

# %%
model.wv.key_to_index
# Out:
# {'the': 0,
#  '.': 1,
#  ',': 2,
#  'of': 3,
#  '“': 4,
#  '”': 5,
#  'to': 6,
#  'a': 7,
#  'and': 8,
#  '’': 9,
#  'that': 10,
#  'in': 11,
#  'was': 12,
#  'it': 13,
#  'is': 14,
#  's': 15,
#  'you': 16,
#  'he': 17,
#  'she': 18,
#  '?': 19,
#  'we': 20,
#  'sophie': 21,
#  'i': 22,
#  'had': 23,
#  'but': 24,
#  'as': 25,
#  'not': 26,
#  'on': 27,
#  '%': 28,
#  'her': 29,
#  'for': 30,
#  'have': 31,
#  'be': 32,
#  'with': 33,
#  ':': 34,
#  'are': 35,
#  'what': 36,
#  'from': 37,
#  'all': 38,
#  'this': 39,
#  'they': 40,
#  'can': 41,
#  'there': 42,
#  'at': 43,
#  't': 44,
#  'world': 45,
#  'or': 46,
#  'one': 47,
#  'so': 48,
#  '‘': 49,
#  'his': 50,
#  'were': 51,
#  'an': 52,
#  'about': 53,
#  'by': 54,
#  'could': 55,
#  'when': 56,
#  '...': 57,
#  '!': 58,
#  'said': 59,
#  'if': 60,
#  'up': 61,
#  'no': 62,
#  'who': 63,
#  'only': 64,
#  'would': 65,
#  'hilde': 66,
#  'also': 67,
#  'more': 68,
#  'into': 69,
#  'out': 70,
#  'time': 71,
#  'like': 72,
#  'just': 73,
#  'now': 74,
#  'which': 75,
#  'how': 76,
#  'alberto': 77,
#  'do': 78,
#  'something': 79,
#  'way': 80,
#  'god': 81,
#  'our': 82,
#  'will': 83,
#  'been': 84,
#  'then': 85,
#  'has': 86,
#  'other': 87,
#  'because': 88,
#  'man': 89,
#  'people': 90,
#  'same': 91,
#  'page': 92,
#  'think': 93,
#  'life': 94,
#  'say': 95,
#  'thought': 96,
#  'philosophy': 97,
#  'file': 98,
#  '258': 99,
#  '//c': 100,
#  '9/13/2004': 101,
#  '\\temp\\emule\\incoming\\sophie': 102,
#  "'s": 103,
#  'must': 104,
#  '20world': 105,
#  '20-': 106,
#  '20jostien': 107,
#  '20gaarder.h': 108,
#  'before': 109,
#  'own': 110,
#  'down': 111,
#  'did': 112,
#  'their': 113,
#  'see': 114,
#  'over': 115,
#  'us': 116,
#  'yes': 117,
#  'nature': 118,
#  'know': 119,
#  'everything': 120,
#  'him': 121,
#  'between': 122,
#  'after': 123,
#  'them': 124,
#  'two': 125,
#  'mother': 126,
#  'first': 127,
#  'new': 128,
#  'some': 129,
#  'little': 130,
#  'right': 131,
#  'very': 132,
#  'these': 133,
#  'even': 134,
#  'than': 135,
#  'many': 136,
#  'things': 137,
#  'reason': 138,
#  'both': 139,
#  'again': 140,
#  'get': 141,
#  'why': 142,
#  'your': 143,
#  'my': 144,
#  'its': 145,
#  'called': 146,
#  'back': 147,
#  'any': 148,
#  'old': 149,
#  'plato': 150,
#  'around': 151,
#  'me': 152,
#  'through': 153,
#  'human': 154,
#  'go': 155,
#  'don': 156,
#  'm': 157,
#  'here': 158,
#  'years': 159,
#  'most': 160,
#  'being': 161,
#  'went': 162,
#  'came': 163,
#  'come': 164,
#  'such': 165,
#  'too': 166,
#  'day': 167,
#  'really': 168,
#  'idea': 169,
#  'made': 170,
#  'never': 171,
#  'where': 172,
#  'philosopher': 173,
#  'believed': 174,
#  'thing': 175,
#  'got': 176,
#  'began': 177,
#  'natural': 178,
#  'father': 179,
#  'll': 180,
#  'read': 181,
#  'good': 182,
#  'philosophers': 183,
#  'home': 184,
#  'aristotle': 185,
#  'well': 186,
#  'let': 187,
#  'another': 188,
#  'great': 189,
#  'long': 190,
#  'put': 191,
#  'going': 192,
#  'major': 193,
#  'garden': 194,
#  'ideas': 195,
#  'much': 196,
#  'whole': 197,
#  'mean': 198,
#  'once': 199,
#  ')': 200,
#  'example': 201,
#  'birthday': 202,
#  'nothing': 203,
#  '(': 204,
#  'important': 205,
#  'history': 206,
#  'quite': 207,
#  'looked': 208,
#  'socrates': 209,
#  'joanna': 210,
#  'still': 211,
#  'always': 212,
#  'mind': 213,
#  'earth': 214,
#  'question': 215,
#  'does': 216,
#  'course': 217,
#  'didn': 218,
#  'different': 219,
#  'may': 220,
#  'himself': 221,
#  'soul': 222,
#  'find': 223,
#  'person': 224,
#  'sat': 225,
#  'therefore': 226,
#  'call': 227,
#  'philosophical': 228,
#  'make': 229,
#  'should': 230,
#  'suddenly': 231,
#  'point': 232,
#  'greek': 233,
#  'water': 234,
#  'felt': 235,
#  'each': 236,
#  'book': 237,
#  'away': 238,
#  'am': 239,
#  'while': 240,
#  'last': 241,
#  'living': 242,
#  'might': 243,
#  'today': 244,
#  'white': 245,
#  'table': 246,
#  'few': 247,
#  'means': 248,
#  'seen': 249,
#  'every': 250,
#  'hand': 251,
#  'sure': 252,
#  'probably': 253,
#  'descartes': 254,
#  'room': 255,
#  'believe': 256,
#  'give': 257,
#  'kant': 258,
#  're': 259,
#  'take': 260,
#  'middle': 261,
#  'since': 262,
#  'took': 263,
#  'true': 264,
#  'without': 265,
#  'whether': 266,
#  'lived': 267,
#  'fact': 268,
#  'dream': 269,
#  'work': 270,
#  'anything': 271,
#  'perhaps': 272,
#  'found': 273,
#  'sense': 274,
#  'kind': 275,
#  'live': 276,
#  'girl': 277,
#  'part': 278,
#  'questions': 279,
#  'exactly': 280,
#  'thus': 281,
#  'lot': 282,
#  'written': 283,
#  'society': 284,
#  'church': 285,
#  'tried': 286,
#  'form': 287,
#  'words': 288,
#  'three': 289,
#  'athens': 290,
#  'next': 291,
#  'red': 292,
#  'became': 293,
#  'herself': 294,
#  'envelope': 295,
#  'certain': 296,
#  'itself': 297,
#  'stood': 298,
#  'saw': 299,
#  'thinking': 300,
#  'letter': 301,
#  'already': 302,
#  'hume': 303,
#  ';': 304,
#  'big': 305,
#  'look': 306,
#  'ages': 307,
#  've': 308,
#  'far': 309,
#  'universe': 310,
#  'asked': 311,
#  'word': 312,
#  'animals': 313,
#  'actually': 314,
#  'tell': 315,
#  'knowledge': 316,
#  'heard': 317,
#  'darwin': 318,
#  'talk': 319,
#  'least': 320,
#  'almost': 321,
#  'christian': 322,
#  'body': 323,
#  'school': 324,
#  'reality': 325,
#  'century': 326,
#  'according': 327,
#  'view': 328,
#  'door': 329,
#  'end': 330,
#  'toward': 331,
#  'maybe': 332,
#  'off': 333,
#  'under': 334,
#  'marx': 335,
#  'women': 336,
#  'knew': 337,
#  'meant': 338,
#  'become': 339,
#  'hegel': 340,
#  'wrong': 341,
#  'soon': 342,
#  'free': 343,
#  'turned': 344,
#  'experience': 345,
#  'until': 346,
#  'wasn': 347,
#  'understand': 348,
#  'picture': 349,
#  'later': 350,
#  'eyes': 351,
#  'ever': 352,
#  'comes': 353,
#  'remember': 354,
#  'left': 355,
#  'existence': 356,
#  'times': 357,
#  'real': 358,
#  'large': 359,
#  'spirit': 360,
#  'lebanon': 361,
#  'either': 362,
#  'wrote': 363,
#  'else': 364,
#  'matter': 365,
#  'ran': 366,
#  'woods': 367,
#  'bed': 368,
#  'name': 369,
#  'card': 370,
#  'neither': 371,
#  'completely': 372,
#  'together': 373,
#  'renaissance': 374,
#  'state': 375,
#  'horse': 376,
#  'present': 377,
#  'house': 378,
#  'top': 379,
#  'ask': 380,
#  'those': 381,
#  'dear': 382,
#  'enough': 383,
#  'themselves': 384,
#  'although': 385,
#  'law': 386,
#  'christianity': 387,
#  'across': 388,
#  'knag': 389,
#  'talking': 390,
#  'cabin': 391,
#  'started': 392,
#  'sitting': 393,
#  'better': 394,
#  'cause': 395,
#  'freud': 396,
#  'certainly': 397,
#  'love': 398,
#  'against': 399,
#  'during': 400,
#  'child': 401,
#  'single': 402,
#  'head': 403,
#  'someone': 404,
#  'wanted': 405,
#  'hermes': 406,
#  'behind': 407,
#  'jesus': 408,
#  'light': 409,
#  'substance': 410,
#  'inside': 411,
#  'party': 412,
#  'morning': 413,
#  'material': 414,
#  'gods': 415,
#  'shall': 416,
#  'animal': 417,
#  'possible': 418,
#  'opened': 419,
#  'senses': 420,
#  'imagine': 421,
#  'several': 422,
#  'period': 423,
#  'front': 424,
#  'number': 425,
#  'dad': 426,
#  'finally': 427,
#  'saying': 428,
#  'bit': 429,
#  'culture': 430,
#  'need': 431,
#  'want': 432,
#  'story': 433,
#  'answer': 434,
#  'art': 435,
#  'men': 436,
#  'happened': 437,
#  'chicken': 438,
#  'feel': 439,
#  'young': 440,
#  'clear': 441,
#  'religious': 442,
#  'place': 443,
#  'small': 444,
#  'happens': 445,
#  'having': 446,
#  'eternal': 447,
#  'side': 448,
#  'looking': 449,
#  'hear': 450,
#  'kierkegaard': 451,
#  'un': 452,
#  'nor': 453,
#  'thoughts': 454,
#  'walked': 455,
#  'theory': 456,
#  'used': 457,
#  'four': 458,
#  'space': 459,
#  'often': 460,
#  'meet': 461,
#  'rabbit': 462,
#  'laws': 463,
#  'night': 464,
#  'pointed': 465,
#  'mom': 466,
#  'simply': 467,
#  'held': 468,
#  'path': 469,
#  'set': 470,
#  'sun': 471,
#  'ring': 472,
#  'trees': 473,
#  'change': 474,
#  'created': 475,
#  'mirror': 476,
#  'experienced': 477,
#  'town': 478,
#  'see.': 479,
#  'doesn': 480,
#  'moment': 481,
#  'isn': 482,
#  'keep': 483,
#  'yourself': 484,
#  'individual': 485,
#  'science': 486,
#  'help': 487,
#  'age': 488,
#  'air': 489,
#  'less': 490,
#  'difference': 491,
#  'woman': 492,
#  'happen': 493,
#  'mankind': 494,
#  'particular': 495,
#  'death': 496,
#  'forms': 497,
#  'window': 498,
#  'outside': 499,
#  'democritus': 500,
#  'ourselves': 501,
#  'ago': 502,
#  'case': 503,
#  'faith': 504,
#  'happy': 505,
#  'tiny': 506,
#  'mailbox': 507,
#  'spinoza': 508,
#  'yet': 509,
#  'clock': 510,
#  'beginning': 511,
#  'couldn': 512,
#  'that.': 513,
#  'rather': 514,
#  'lay': 515,
#  'told': 516,
#  'stone': 517,
#  'above': 518,
#  'europe': 519,
#  'though': 520,
#  'binder': 521,
#  'dog': 522,
#  'it.': 523,
#  'turn': 524,
#  'order': 525,
#  'species': 526,
#  'able': 527,
#  'st.': 528,
#  'deep': 529,
#  'd': 530,
#  'given': 531,
#  'try': 532,
#  'gave': 533,
#  'common': 534,
#  'start': 535,
#  'trying': 536,
#  'force': 537,
#  'o': 538,
#  'best': 539,
#  'early': 540,
#  'berkeley': 541,
#  'perceive': 542,
#  'food': 543,
#  'especially': 544,
#  'precisely': 545,
#  'teacher': 546,
#  'however': 547,
#  'past': 548,
#  'gets': 549,
#  'use': 550,
#  'black': 551,
#  'everyone': 552,
#  'open': 553,
#  'amundsen': 554,
#  'others': 555,
#  'gone': 556,
#  'born': 557,
#  'onto': 558,
#  'explanation': 559,
#  'fall': 560,
#  'various': 561,
#  'known': 562,
#  'says': 563,
#  'cards': 564,
#  'exists': 565,
#  'enlightenment': 566,
#  'brought': 567,
#  'french': 568,
#  'explain': 569,
#  'parts': 570,
#  'days': 571,
#  'round': 572,
#  'makes': 573,
#  'city': 574,
#  'sometimes': 575,
#  'stage': 576,
#  'romantics': 577,
#  'existed': 578,
#  'lives': 579,
#  'power': 580,
#  'religion': 581,
#  'children': 582,
#  'albert': 583,
#  'within': 584,
#  'lake': 585,
#  'getting': 586,
#  'learned': 587,
#  'square': 588,
#  'nevertheless': 589,
#  'simple': 590,
#  'coming': 591,
#  'moon': 592,
#  'clearly': 593,
#  'second': 594,
#  'den': 595,
#  'innate': 596,
#  'mysterious': 597,
#  'alive': 598,
#  'bad': 599,
#  'moral': 600,
#  'augustine': 601,
#  'note': 602,
#  'kingdom': 603,
#  'bigger': 604,
#  'belief': 605,
#  'changes': 606,
#  'standing': 607,
#  'haven': 608,
#  'kitchen': 609,
#  'hardly': 610,
#  'begun': 611,
#  'locke': 612,
#  'doing': 613,
#  'truth': 614,
#  'died': 615,
#  'grow': 616,
#  'claimed': 617,
#  'problem': 618,
#  'begin': 619,
#  'coffee': 620,
#  'further': 621,
#  'marble': 622,
#  'hundred': 623,
#  'longer': 624,
#  'car': 625,
#  'seemed': 626,
#  'hours': 627,
#  'fire': 628,
#  'moreover': 629,
#  'dark': 630,
#  'unconscious': 631,
#  'reading': 632,
#  'evolution': 633,
#  'ancient': 634,
#  'expression': 635,
#  'gradually': 636,
#  'short': 637,
#  'taken': 638,
#  'continued': 639,
#  'noticed': 640,
#  'exist': 641,
#  'easy': 642,
#  'surely': 643,
#  'oh': 644,
#  'norwegian': 645,
#  'b.c': 646,
#  'run': 647,
#  'figure': 648,
#  'year': 649,
#  'knox': 650,
#  'cave': 651,
#  'humans': 652,
#  'political': 653,
#  'done': 654,
#  'strange': 655,
#  'bible': 656,
#  'showed': 657,
#  'books': 658,
#  'late': 659,
#  'evil': 660,
#  'basic': 661,
#  'decided': 662,
#  'everybody': 663,
#  'hands': 664,
#  'divine': 665,
#  'passed': 666,
#  'couple': 667,
#  'absolutely': 668,
#  'conditions': 669,
#  'floor': 670,
#  'face': 671,
#  'half': 672,
#  'ten': 673,
#  'interested': 674,
#  'hair': 675,
#  'situation': 676,
#  'sea': 677,
#  'concerned': 678,
#  'sit': 679,
#  'step': 680,
#  'cat': 681,
#  'pages': 682,
#  'family': 683,
#  'lost': 684,
#  'planet': 685,
#  'boat': 686,
#  'goes': 687,
#  'antiquity': 688,
#  'green': 689,
#  'hedge': 690,
#  'wall': 691,
#  'process': 692,
#  'language': 693,
#  'sartre': 694,
#  'tree': 695,
#  'feeling': 696,
#  'nobody': 697,
#  'bottle': 698,
#  'ought': 699,
#  'perfect': 700,
#  'alone': 701,
#  'among': 702,
#  'consciousness': 703,
#  'hard': 704,
#  'significant': 705,
#  'processes': 706,
#  'romanticism': 707,
#  'return': 708,
#  'thousand': 709,
#  'attention': 710,
#  'ability': 711,
#  'brown': 712,
#  'letters': 713,
#  'struggle': 714,
#  'reflection': 715,
#  'wouldn': 716,
#  'close': 717,
#  'watch': 718,
#  'reached': 719,
#  'class': 720,
#  'baroque': 721,
#  'actual': 722,
#  'mystery': 723,
#  'philosophic': 724,
#  'led': 725,
#  'stop': 726,
#  'along': 727,
#  'move': 728,
#  'sensory': 729,
#  'atoms': 730,
#  'immutable': 731,
#  'movement': 732,
#  'central': 733,
#  'universal': 734,
#  'acropolis': 735,
#  'won': 736,
#  'blue': 737,
#  'daughter': 738,
#  'main': 739,
#  'june': 740,
#  'obviously': 741,
#  'developed': 742,
#  'due': 743,
#  'suppose': 744,
#  '*': 745,
#  'imagination': 746,
#  'gate': 747,
#  'instance': 748,
#  'agreed': 749,
#  'wait': 750,
#  'talked': 751,
#  'rome': 752,
#  'basis': 753,
#  'takes': 754,
#  'sight': 755,
#  'speak': 756,
#  'p.s': 757,
#  'entire': 758,
#  'rights': 759,
#  'plants': 760,
#  'historical': 761,
#  'chapter': 762,
#  'usually': 763,
#  'ground': 764,
#  'arrived': 765,
#  'relationship': 766,
#  'minute': 767,
#  'discovered': 768,
#  'indeed': 769,
#  'significance': 770,
#  'stars': 771,
#  'write': 772,
#  'romantic': 773,
#  'five': 774,
#  'boy': 775,
#  'plane': 776,
#  'paper': 777,
#  'horses': 778,
#  'forces': 779,
#  'somewhere': 780,
#  'apple': 781,
#  'leave': 782,
#  'method': 783,
#  'whatever': 784,
#  'roman': 785,
#  'formed': 786,
#  'walk': 787,
#  'life.': 788,
#  'considered': 789,
#  'rest': 790,
#  'fifteen': 791,
#  'moller': 792,
#  'needs': 793,
#  'hung': 794,
#  'conscience': 795,
#  'met': 796,
#  'knows': 797,
#  'third': 798,
#  'doubt': 799,
#  'opposite': 800,
#  'center': 801,
#  'voice': 802,
#  'ball': 803,
#  'midsummer': 804,
#  'characteristic': 805,
#  'complex': 806,
#  'meaning': 807,
#  'sophists': 808,
#  'creatures': 809,
#  'play': 810,
#  'hope': 811,
#  'us.': 812,
#  'physical': 813,
#  'sorry': 814,
#  'huge': 815,
#  'prove': 816,
#  'sounds': 817,
#  'pulled': 818,
#  'blocks': 819,
#  'thor': 820,
#  'realized': 821,
#  'system': 822,
#  'die': 823,
#  'bodies': 824,
#  'cell': 825,
#  'cultures': 826,
#  'nowadays': 827,
#  'quickly': 828,
#  'medieval': 829,
#  'poor': 830,
#  'production': 831,
#  'planets': 832,
#  'eye': 833,
#  'lillesand': 834,
#  'published': 835,
#  'greeks': 836,
#  'fifteenth': 837,
#  'postcard': 838,
#  'money': 839,
#  'line': 840,
#  'high': 841,
#  'kinds': 842,
#  'totally': 843,
#  'effect': 844,
#  'followed': 845,
#  'built': 846,
#  'secret': 847,
#  'thank': 848,
#  'nodded': 849,
#  'elements': 850,
#  'truths': 851,
#  'empty': 852,
#  'freedom': 853,
#  'summer': 854,
#  'wonder': 855,
#  'forget': 856,
#  'shadows': 857,
#  'anyway': 858,
#  'roots': 859,
#  'paul': 860,
#  'instead': 861,
#  'environment': 862,
#  'piece': 863,
#  'looks': 864,
#  'writing': 865,
#  'personal': 866,
#  'forward': 867,
#  'difficult': 868,
#  'bjerkely': 869,
#  'plant': 870,
#  'managed': 871,
#  'equally': 872,
#  'belong': 873,
#  'smaller': 874,
#  'wish': 875,
#  'complicated': 876,
#  'seven': 877,
#  'fate': 878,
#  'beyond': 879,
#  'lego': 880,
#  'me.': 881,
#  'answers': 882,
#  'german': 883,
#  'so-called': 884,
#  'plan': 885,
#  'rose': 886,
#  'straight': 887,
#  'care': 888,
#  'myths': 889,
#  'following': 890,
#  'hammer': 891,
#  'full': 892,
#  'emphasized': 893,
#  'realize': 894,
#  'taking': 895,
#  '15': 896,
#  'gold': 897,
#  'flower': 898,
#  'religions': 899,
#  'kept': 900,
#  'empedocles': 901,
#  'sky': 902,
#  'creature': 903,
#  'jumped': 904,
#  'theater': 905,
#  'absolute': 906,
#  'evening': 907,
#  'stopped': 908,
#  'anyone': 909,
#  'aware': 910,
#  'cultural': 911,
#  'impossible': 912,
#  'hold': 913,
#  'development': 914,
#  'characterized': 915,
#  'aquinas': 916,
#  'sort': 917,
#  'purely': 918,
#  'term': 919,
#  'sound': 920,
#  'dead': 921,
#  'accept': 922,
#  'guess': 923,
#  'possibly': 924,
#  'constant': 925,
#  'western': 926,
#  'strong': 927,
#  'influence': 928,
#  'interest': 929,
#  'reach': 930,
#  'odd': 931,
#  'hot': 932,
#  'approach': 933,
#  'examples': 934,
#  'asleep': 935,
#  'choose': 936,
#  'fifty': 937,
#  'lots': 938,
#  'tells': 939,
#  'sharp': 940,
#  'eight': 941,
#  'video': 942,
#  'goose': 943,
#  'shadow': 944,
#  'screen': 945,
#  'heavy': 946,
#  'newton': 947,
#  'scientific': 948,
#  'control': 949,
#  'characteristics': 950,
#  'learn': 951,
#  'decide': 952,
#  'sophie.': 953,
#  'pass': 954,
#  'god.': 955,
#  'recall': 956,
#  'figures': 957,
#  'general': 958,
#  'upon': 959,
#  'greatest': 960,
#  'okay': 961,
#  'time.': 962,
#  'waiting': 963,
#  'staring': 964,
#  'heraclitus': 965,
#  'eve': 966,
#  'drawn': 967,
#  'copenhagen': 968,
#  'study': 969,
#  'chance': 970,
#  'guests': 971,
#  'rejected': 972,
#  'creation': 973,
#  'remained': 974,
#  'merely': 975,
#  'constantly': 976,
#  'desk': 977,
#  'dreams': 978,
#  'special': 979,
#  'becomes': 980,
#  'conscious': 981,
#  'sleep': 982,
#  'disappeared': 983,
#  'preoccupied': 984,
#  'ethics': 985,
#  'using': 986,
#  'minutes': 987,
#  'mouth': 988,
#  'wearing': 989,
#  'mentioned': 990,
#  'holding': 991,
#  'insight': 992,
#  'fair': 993,
#  'outer': 994,
#  'typical': 995,
#  'making': 996,
#  'beside': 997,
#  'war': 998,
#  'create': 999,
#  ...}

# %%
model.wv.get_vector("god", norm=True)
# Out:
# array([-0.12527429,  0.08391813,  0.05088614, -0.04522224,  0.02552596,
#        -0.20340374, -0.08024218,  0.23262402, -0.0780087 ,  0.01076856,
#        -0.05041265, -0.00207931,  0.020677  ,  0.01216055,  0.18838915,
#        -0.15410101,  0.054657  , -0.07327761, -0.0267128 , -0.15742199,
#         0.01731358,  0.1178474 ,  0.03889998, -0.11730106, -0.08910057,
#         0.08192901, -0.05455297, -0.00568153, -0.11620684,  0.11597855,
#         0.00655408, -0.14244886,  0.23710677, -0.05348522, -0.01085391,
#         0.01188662, -0.02279246, -0.07816391, -0.04727737, -0.12645377,
#        -0.04406005, -0.16110128,  0.01848601,  0.06678816,  0.01126639,
#         0.01387555, -0.08106496,  0.08720741,  0.01939199,  0.03318356,
#         0.0260732 ,  0.02095755,  0.01886974, -0.12209618, -0.0879849 ,
#        -0.01630256,  0.07962065,  0.03515428, -0.00189329,  0.06965647,
#        -0.02629514,  0.10078038, -0.01586703,  0.02111634, -0.03875082,
#         0.20899162,  0.05527729,  0.21375316, -0.23450924,  0.16845594,
#         0.00405776, -0.0134597 ,  0.10199425, -0.04603652,  0.10940187,
#        -0.01450682,  0.19079742,  0.05909096, -0.09654938, -0.01735109,
#        -0.22026625,  0.01741781, -0.14102024,  0.11030314,  0.03123212,
#        -0.03163428, -0.03148784,  0.00387574,  0.17307988,  0.1202337 ,
#         0.11019878, -0.02213223,  0.05799928,  0.03761319,  0.09043761,
#         0.1099617 ,  0.16714774,  0.00248196, -0.18208313, -0.1150367 ],
#       dtype=float32)

# %%
model.wv.most_similar('god')
# Out:
# [('man', 0.9774328470230103),
#  ('or', 0.9613156914710999),
#  ('reason', 0.9446678161621094),
#  ('means', 0.9392219185829163),
#  ('—that', 0.9383209347724915),
#  ('this', 0.9351164698600769),
#  ('nature', 0.9304097294807434),
#  ('plato', 0.9285739064216614),
#  ('soul', 0.9242190718650818),
#  ('everything', 0.9178557395935059)]

# %%
model.wv.most_similar('love')
# Out:
# [('figure', 0.9964097142219543),
#  ('eggs', 0.9962760806083679),
#  ('goes', 0.9957298636436462),
#  ('epicurus', 0.9954367280006409),
#  ('hold', 0.9951100945472717),
#  ('naturally', 0.994994044303894),
#  ('nevertheless', 0.9944711327552795),
#  ('chocolate', 0.9944096207618713),
#  ('late', 0.9943947196006775),
#  ('game', 0.9943339824676514)]

# %%
#model.wv.similarity('mind', 'idea')

# %%
#model.wv.similarity('world', 'question')

# %%
model.wv.similarity('philosopher', 'question')
# Out:
# 0.97886485

# %%
import warnings

# Ignore the specific t-SNE warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn.manifold._t_sne")

def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    # extract the words & their vectors, as numpy arrays
    vectors = np.asarray(model.wv.vectors)
    labels = np.asarray(model.wv.index_to_key)  # fixed-width numpy strings

    # reduce using t-SNE
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels


x_vals, y_vals, labels = reduce_dimensions(model)
warnings.filterwarnings("default")

# %%
import warnings

# Function to suppress the DeprecationWarning
def warn(*args, **kwargs):
    pass

warnings.filterwarnings("ignore", category=DeprecationWarning)  # Suppress the DeprecationWarning
warnings.warn = warn

from plotly.offline import init_notebook_mode, iplot, plot
import plotly.graph_objs as go

def plot_with_plotly(x_vals, y_vals, labels, plot_in_notebook=True):
    from plotly.offline import init_notebook_mode, iplot, plot
    import plotly.graph_objs as go

    trace = go.Scatter(x=x_vals, y=y_vals, mode='text', text=labels)
    data = [trace]

    if plot_in_notebook:
        init_notebook_mode(connected=True)
        iplot(data, filename='word-embedding-plot')
    else:
        plot(data, filename='word-embedding-plot.html')


def plot_with_matplotlib(x_vals, y_vals, labels):
    import matplotlib.pyplot as plt
    import random

    random.seed(0)

    plt.figure(figsize=(12, 12))
    plt.scatter(x_vals, y_vals)

    #
    # Label randomly subsampled 25 data points
    #
    indices = list(range(len(labels)))
    selected_indices = random.sample(indices, 25)
    for i in selected_indices:
        plt.annotate(labels[i], (x_vals[i], y_vals[i]))

try:
    get_ipython()
except Exception:
    plot_function = plot_with_matplotlib
else:
    plot_function = plot_with_plotly

plot_function(x_vals, y_vals, labels)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="72917127-ab06-431b-80b4-a6f01da6b02f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72917127-ab06-431b-80b4-a6f01da6b02f")) {                    Plotly.newPlot(                        "72917127-ab06-431b-80b4-a6f01da6b02f",                        [{"mode":"text","text":["the",".",",","of","\u201c","\u201d","to","a","and","\u2019","that","in","was","it","is","s","you","he","she","?","we","sophie","i","had","but","as","not","on","%","her","for","have","be","with",":","are","what","from","all","this","they","can","there","at","t","world","or","one","so","\u2018","his","were","an","about","by","could","when","...","!","said","if","up","no","who","only","would","hilde","also","more","into","out","time","like","just","now","which","how","alberto","do","something","way","god","our","will","been","then","has","other","because","man","people","same","page","think","life","say","thought","philosophy","file","258","//c","9/13/2004","\\temp\\emule\\incoming\\sophie","'s","must","20world","20-","20jostien","20gaarder.h","before","own","down","did","their","see","over","us","yes","nature","know","everything","him","between","after","them","two","mother","first","new","some","little","right","very","these","even","than","many","things","reason","both","again","get","why","your","my","its","called","back","any","old","plato","around","me","through","human","go","don","m","here","years","most","being","went","came","come","such","too","day","really","idea","made","never","where","philosopher","believed","thing","got","began","natural","father","ll","read","good","philosophers","home","aristotle","well","let","another","great","long","put","going","major","garden","ideas","much","whole","mean","once",")","example","birthday","nothing","(","important","history","quite","looked","socrates","joanna","still","always","mind","earth","question","does","course","didn","different","may","himself","soul","find","person","sat","therefore","call","philosophical","make","should","suddenly","point","greek","water","felt","each","book","away","am","while","last","living","might","today","white","table","few","means","seen","every","hand","sure","probably","descartes","room","believe","give","kant","re","take","middle","since","took","true","without","whether","lived","fact","dream","work","anything","perhaps","found","sense","kind","live","girl","part","questions","exactly","thus","lot","written","society","church","tried","form","words","three","athens","next","red","became","herself","envelope","certain","itself","stood","saw","thinking","letter","already","hume",";","big","look","ages","ve","far","universe","asked","word","animals","actually","tell","knowledge","heard","darwin","talk","least","almost","christian","body","school","reality","century","according","view","door","end","toward","maybe","off","under","marx","women","knew","meant","become","hegel","wrong","soon","free","turned","experience","until","wasn","understand","picture","later","eyes","ever","comes","remember","left","existence","times","real","large","spirit","lebanon","either","wrote","else","matter","ran","woods","bed","name","card","neither","completely","together","renaissance","state","horse","present","house","top","ask","those","dear","enough","themselves","although","law","christianity","across","knag","talking","cabin","started","sitting","better","cause","freud","certainly","love","against","during","child","single","head","someone","wanted","hermes","behind","jesus","light","substance","inside","party","morning","material","gods","shall","animal","possible","opened","senses","imagine","several","period","front","number","dad","finally","saying","bit","culture","need","want","story","answer","art","m ...

# %% [markdown]
# Visualizing a Smaller Sample of 300 Words

# %%
import warnings

# Ignore the warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn.manifold._t_sne")

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

def reduce_dimensions(model, num_words_to_display=100):
    # Extract the words and their vectors
    words = list(model.wv.index_to_key)
    vectors = [model.wv[word] for word in words]

    # Reduce dimensions using t-SNE
    tsne = TSNE(n_components=2, random_state=0)
    vectors_2D = tsne.fit_transform(vectors[:num_words_to_display])

    return vectors_2D, words

# Define the number of words you want to display
num_words_to_display = 300

# Replace 'model' with your loaded word vector model
vectors_2D, words = reduce_dimensions(model, num_words_to_display)

# Plot the word vectors
plt.figure(figsize=(12, 12))
for i, label in enumerate(words[:num_words_to_display]):
    x, y = vectors_2D[i]
    plt.scatter(x, y)
    plt.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points')

plt.show()
warnings.filterwarnings("default")

# %% [markdown]
# In the visualizations, we notice that some words stick together. For instance, words like "god," "spirit," and "angel" are huddled, hinting at something spiritual. Then, names like "Alberto," "Hilde," and "Sophie" are bunched up, pointing to key characters. Words like "philosopher" and "question" are cozy, showing a connection between deep thinking and inquiry. Also, words like "mother," "father," and "home" gather, suggesting a family connection.

# %% [markdown]
# Part 2: GloVe

# %%
import numpy as np
from scipy import spatial
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
embeddings_dict = {}

# %%
with open("glove.6B.100d.txt", 'r', encoding="utf-8") as f:
  for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %%
def find_closest_embeddings(embedding):
    return sorted(embeddings_dict.keys(), key=lambda word: spatial.distance.euclidean(embeddings_dict[word], embedding))

# %%
lambda word: spatial.distance.euclidean(embeddings_dict[word], embedding)
# Out:
# <function __main__.<lambda>(word)>

# %%
find_closest_embeddings(embeddings_dict["philosopher"])
# Out:
# ['philosopher',
#  'mathematician',
#  'theologian',
#  'thinker',
#  'philosophers',
#  'scholar',
#  'logician',
#  'historian',
#  'sociologist',
#  'poet',
#  'linguist',
#  'theorist',
#  'orientalist',
#  'geographer',
#  'satirist',
#  'novelist',
#  'author',
#  'anthropologist',
#  'polymath',
#  'idealist',
#  'philologist',
#  'musicologist',
#  'thinkers',
#  'dramatist',
#  'naturalist',
#  'nietzsche',
#  'jurist',
#  'realist',
#  'existentialist',
#  'psychoanalyst',
#  'essayist',
#  'humorist',
#  'classicist',
#  'archaeologist',
#  'egyptologist',
#  'astronomer',
#  'chemist',
#  'educator',
#  'ethnologist',
#  'sinologist',
#  'disciple',
#  'grammarian',
#  'epictetus',
#  'clergyman',
#  'modernist',
#  'biographer',
#  'humanist',
#  'wittgenstein',
#  'painter',
#  'archeologist',
#  'physicist',
#  'ethnographer',
#  'storyteller',
#  'educationist',
#  'philosophy',
#  'enlightenment',
#  'sculptor',
#  'medievalist',
#  'metaphysician',
#  'derrida',
#  'kierkegaard',
#  'scientist',
#  'heraclitus',
#  'voltaire',
#  'rousseau',
#  'geologist',
#  'indologist',
#  'immanuel',
#  'chronicler',
#  'folklorist',
#  'inventor',
#  'lucian',
#  'pythagoras',
#  'conservationist',
#  'rhetorician',
#  'kabbalist',
#  'pragmatist',
#  'anaxagoras',
#  'reformer',
#  'aristocrat',
#  'epicurus',
#  'visionary',
#  'biochemist',
#  'coined',
#  'descartes',
#  'neoplatonist',
#  'plato',
#  'futurist',
#  'neoplatonic',
#  'zoologist',
#  'mathematicians',
#  'newspaperman',
#  'postmodern',
#  'cynic',
#  'orator',
#  'theologians',
#  'mencius',
#  'educationalist',
#  'metaphysical',
#  'memoirist',
#  'alchemist',
#  'rationalist',
#  'traveller',
#  'lexicographer',
#  'mozi',
#  'poets',
#  'follower',
#  'astrologer',
#  'wordsmith',
#  'schopenhauer',
#  'anatomist',
#  'heidegger',
#  'existentialism',
#  'empiricist',
#  'machiavelli',
#  'marcuse',
#  'postmodernist',
#  'writer',
#  'writings',
#  'adventurer',
#  'thomist',
#  'jean-jacques',
#  'layman',
#  'blogger',
#  'co-author',
#  'psychologist',
#  'herbalist',
#  'symbolist',
#  'contemporaries',
#  'phenomenologist',
#  'authors',
#  'lucretius',
#  'aristotle',
#  'proclus',
#  'bibliographer',
#  'treatise',
#  'astrophysicist',
#  'historiography',
#  'portraitist',
#  'goalies_montreal',
#  'søren',
#  'renowned',
#  'sophist',
#  'theosophist',
#  'occultist',
#  'exegete',
#  'sociologists',
#  'spinoza',
#  'mystic',
#  'empedocles',
#  'modernists',
#  'humanism',
#  'encyclopedist',
#  'canonist',
#  'genius',
#  'woodcarver',
#  'scribe',
#  'antiquary',
#  'cartographer',
#  'maritain',
#  'schoolmaster',
#  'environmentalist',
#  'ufologist',
#  'mineralogist',
#  'feminist',
#  'protégé',
#  'mentor',
#  'monk',
#  'pre-socratic',
#  'caricaturist',
#  'polemicist',
#  'democritus',
#  'anarchist',
#  'eminent',
#  'deconstructionist',
#  'physician',
#  'colleague',
#  'numismatist',
#  'calligrapher',
#  'theologist',
#  'invented',
#  'al-biruni',
#  'palaeontologist',
#  'laozi',
#  'geneticist',
#  'mommsen',
#  'hegel',
#  'ornithologist',
#  'remarked',
#  'rorty',
#  'neo-confucian',
#  'describes',
#  'al-kindi',
#  'popularized',
#  'nineteenth-century',
#  'pedagogue',
#  'hebraist',
#  'logicians',
#  'santayana',
#  'positivist',
#  'story-teller',
#  'psychotherapist',
#  'befriended',
#  'modernism',
#  'playwright',
#  'vitruvius',
#  'exemplified',
#  'filmmaker',
#  'theophrastus',
#  'ethologist',
#  'atisha',
#  'theorists',
#  'post-structuralist',
#  'émile',
#  'metaphysics',
#  'pseudonym',
#  'rationalism',
#  'intellectuals',
#  'rbi_mcgwire',
#  'runs_pujols',
#  'litterateur',
#  'ethnomusicologist',
#  'agriculturist',
#  'ephorus',
#  'industrialist',
#  'veerashaiva',
#  'triples_deshields',
#  'woodworker',
#  'sexologist',
#  'bard',
#  'cabinetmaker',
#  'propounded',
#  'žižek',
#  'chomsky',
#  'hippocrates',
#  'transcendentalist',
#  'skeptic',
#  'germanist',
#  'callimachus',
#  'platonist',
#  'admirer',
#  'statistician',
#  'watercolorist',
#  'innovator',
#  'posited',
#  'stonemason',
#  'neo-platonic',
#  'structuralist',
#  'constructivist',
#  'prehistorian',
#  'schleiermacher',
#  'moralist',
#  'durkheim',
#  'erudite',
#  'philospher',
#  'hypatia',
#  'epicurean',
#  'surrealist',
#  'legalist',
#  'isaac',
#  'hagiography',
#  'eugenicist',
#  'neurophysiologist',
#  'daoist',
#  'lecturer',
#  'clockmaker',
#  'isocrates',
#  'allegory',
#  'hymn-writer',
#  '.2667',
#  'fabulist',
#  'grandfather',
#  'silversmith',
#  'parapsychologist',
#  'goalies_toronto',
#  'locke',
#  'semiotician',
#  'goal_st',
#  'prudentius',
#  'xenophanes',
#  'saadia',
#  'pioneer',
#  'bricklayer',
#  'basavanna',
#  'prof.',
#  'aristotelian',
#  'rufinus',
#  'neuropsychiatrist',
#  'goldsmith',
#  'epigraphist',
#  'courtier',
#  'botanist',
#  'glucksmann',
#  'teetotaler',
#  'gardener',
#  'agriculturalist',
#  'goalies_edmonton',
#  'entrepreneur',
#  'influenced',
#  'novelists',
#  'ascetic',
#  'agronomist',
#  'philosophical',
#  'poetess',
#  'plotinus',
#  'romanticist',
#  'glassblower',
#  'herpetologist',
#  '20th-century',
#  'humourist',
#  'explains',
#  'cryptozoologist',
#  'practitioner',
#  'theopompus',
#  'galen',
#  '353-1175',
#  'postmodernism',
#  'eighteenth-century',
#  'http://www.nrlc.org',
#  'dennett',
#  'viewpoint',
#  'popper',
#  'aesthetician',
#  'zhuangzi',
#  'philosophic',
#  'coauthor',
#  'byzantinist',
#  'con-man',
#  'aesthetics',
#  'lysippos',
#  'diplomatist',
#  'gandhian',
#  'hieromonk',
#  'foucault',
#  'ceramicist',
#  'scholars',
#  'cartoonist',
#  'admired',
#  'skald',
#  'assyriologist',
#  'metallurgist',
#  'individualist',
#  'materialist',
#  'hymnwriter',
#  'epigrapher',
#  'liturgist',
#  'pharmacologist',
#  'opportunities_st',
#  'prohertrib',
#  'thahl',
#  'illustrator',
#  'naturalism',
#  'film-maker',
#  'hymnist',
#  'protagoras',
#  'controversialist',
#  'preacher',
#  'aphorism',
#  'neurologist',
#  'biography',
#  'theology',
#  'historians',
#  'kazin',
#  'goalies_st',
#  'stoic',
#  'popularizer',
#  'enthusiast',
#  'well-known',
#  'mafioso',
#  'boethius',
#  'vonnegut',
#  'ascetical',
#  'improviser',
#  'sigmund',
#  'hölderlin',
#  'esteemed',
#  'ceramist',
#  'philologists',
#  'agitator',
#  'seminarian',
#  'collaborator',
#  'churchman',
#  'journalist',
#  'organgn',
#  'updike',
#  'seventeenth-century',
#  'finkielkraut',
#  'antiquarian',
#  'al-ghazali',
#  'prévert',
#  'literary',
#  'buber',
#  'nobleman',
#  'devotee',
#  'slavoj',
#  'reverend',
#  'rickd',
#  'sartre',
#  'rationalists',
#  'www.slarmy.org',
#  'runs_mcgwire',
#  'caravaggio',
#  'landscaper',
#  'ammonius',
#  'deist',
#  'bergson',
#  'great-grandfather',
#  'regarded',
#  'parmenides',
#  'ascribed',
#  'lactantius',
#  'aesthete',
#  'schelling',
#  'raconteur',
#  'paleontologist',
#  'inspiration',
#  'goalies_san',
#  'chrysippus',
#  'dictum',
#  'al-maqrizi',
#  'hierocles',
#  'eccentric',
#  'mysticism',
#  'rhetoricians',
#  'goalies_philadelphia',
#  'geographers',
#  'exilarch',
#  'oly-2004-fhockey',
#  'carpenter',
#  'woodcutter',
#  'masson',
#  'apologist',
#  'englishman',
#  'restaurateur',
#  'hobbes',
#  'likened',
#  'bacteriologist',
#  'cyberpunk',
#  'avicenna',
#  'tutor',
#  'kant',
#  'mailer',
#  'madhvacharya',
#  'theoretician',
#  'adorno',
#  'wunderkind',
#  'wilfred',
#  'iamblichus',
#  'twentieth-century',
#  'abstractionist',
#  'stamatis',
#  'observes',
#  'pamphleteer',
#  'gassendi',
#  'printmaker',
#  'posidonius',
#  'strikeouts_clemens',
#  'architect',
#  'clarinettist',
#  'http://www.storaenso.com',
#  'paraphrase',
#  'freud',
#  'barth',
#  'farceur',
#  'romanticism',
#  'drohs',
#  'montesquieu',
#  'neo-kantian',
#  'horologist',
#  'autodidact',
#  'kantian',
#  'scribes',
#  'iconoclast',
#  'pseudonymous',
#  'outsider',
#  'watercolourist',
#  'empiricism',
#  'kabbalists',
#  'geodesist',
#  'abbé',
#  'philanthropist',
#  'averroes',
#  '19th-century',
#  'libertine',
#  'philo',
#  'oly-2004-tennis',
#  'brohd',
#  'bukowski',
#  '.2666',
#  'professor',
#  'boyer',
#  'http://www.nwguild.org',
#  'critique',
#  'talmudist',
#  'vedantic',
#  'neo-latin',
#  'ennius',
#  'literature',
#  'http://www.mounteverest.net',
#  'goalies_chicago',
#  'polybius',
#  'cassiodorus',
#  'vidyapati',
#  'em96',
#  'malacologist',
#  'polemic',
#  'oceanographer',
#  'peripatetic',
#  'hobsbawm',
#  'critic',
#  'psychiatrist',
#  'hedonist',
#  'vegetius',
#  'biotechtrst',
#  'travel@latimes.com',
#  'essay',
#  'dioscorides',
#  'bdb94',
#  'loner',
#  'bibliophile',
#  'bulletinyyy',
#  'synthesist',
#  'nobelist',
#  '65stk',
#  'arabist',
#  'archilochus',
#  'credited',
#  'tillich',
#  'structuralism',
#  'tyahn',
#  'k977-1',
#  'k978-1',
#  'mo95',
#  'zealot',
#  'david.lazarus@latimes.com',
#  'biologist',
#  'translator',
#  'genealogist',
#  'treatises',
#  'mountaineer',
#  'ichthyologist',
#  'kd97',
#  'str95bb',
#  'jiddu',
#  'drs.',
#  'phenomenological',
#  'k587-1',
#  'müller',
#  'klopstock',
#  'anthologist',
#  'clerici',
#  'bb96',
#  'miniaturist',
#  'regiomontanus',
#  'landscapist',
#  'mentions',
#  'latinist',
#  'painters',
#  'libanius',
#  'ophthalmologist',
#  'taoist',
#  'saves_nen',
#  'felshtinsky',
#  'baudrillard',
#  'argues',
#  'acquaintance',
#  'http://www.mediabynumbers.com',
#  'js94bb',
#  'diagnostician',
#  'lumberman',
#  'freeskier',
#  'mixologist',
#  'hermeneutics',
#  'horace',
#  'horowitz',
#  'jean-françois',
#  'biographers',
#  'piyanart',
#  'anthropologists',
#  'atomism',
#  'patrick.goldstein@latimes.com',
#  'conceptions',
#  'sculptors',
#  'bb94',
#  'confucianist',
#  'tihg',
#  'srivalo',
#  'megasthenes',
#  'anaximander',
#  'herbert',
#  'sociology',
#  'eubulus',
#  '206-448-8135',
#  'edmund',
#  'rw95',
#  'paracelsus',
#  'al-farabi',
#  'gregorius',
#  'js03',
#  '24aou94',
#  'friedrich',
#  'tabari',
#  'bourdin',
#  'goalies_colorado',
#  'venzuel',
#  'lyotard',
#  'mattheson',
#  'greg.wilcoxdailynews.com',
#  'florentine',
#  'biophysicist',
#  'barthes',
#  'musicologists',
#  'antiquity',
#  'idealists',
#  'ntncom',
#  'crauscher',
#  'neo-impressionist',
#  'abhinavagupta',
#  'althusser',
#  'schoolteacher',
#  'phonetician',
#  'ex-convict',
#  'ramanujacharya',
#  'littérateur',
#  'dk04',
#  'mystical',
#  'jurists',
#  'hephaestion',
#  'mallarme',
#  'nihilism',
#  'jóhannes',
#  'jakobson',
#  'dōgen',
#  'ellul',
#  'shipmaster',
#  'foremost',
#  'speedskatingstats.com',
#  'http://www.oklahomacitynationalmemorial.org',
#  'composer',
#  'showman',
#  'ricoeur',
#  'xunzi',
#  'levinas',
#  'servant',
#  'roboticist',
#  'kd94',
#  'patristic',
#  'kanagy',
#  'aficionado',
#  'drunkard',
#  'js04bb',
#  'gph04bb',
#  'carver',
#  'proponent',
#  'calchas',
#  'bruhth',
#  'http://www.supremecourtus.gov/',
#  'veht',
#  '__________________________________',
#  'jogues',
#  'hagiographer',
#  'socrates',
#  'phenomenology',
#  'bernard-henri',
#  'folklorists',
#  'heraldist',
#  'mann',
#  'str94',
#  'bellow',
#  'phidias',
#  'lutenist',
#  'saves_mrivera',
#  'freethinker',
#  'svahng',
#  'patristics',
#  'ooooooooooooooooooooooooooooooooooooooo',
#  'viticulturist',
#  'hume',
#  'likens',
#  'celsus',
#  'edwin',
#  'formalist',
#  'http://www.lanl.gov',
#  'wc2003-wis',
#  'janlgardner@yahoo.com',
#  'ctesias',
#  'thesiger',
#  'calvinist',
#  'zinn',
#  'cryptographer',
#  'eratosthenes',
#  'naborsind',
#  'habermas',
#  'halberstam',
#  'saves_beck',
#  'simson.net',
#  'theorized',
#  'taught',
#  '3.7504',
#  'ulpian',
#  'http://www.deathpenaltyinfo.org',
#  'http://www.nifc.gov/',
#  'kd96',
#  'al-muqaddasi',
#  'guidebook',
#  'plantsman',
#  'maimonides',
#  'expounded',
#  'pythagoreans',
#  'humanists',
#  'ironically',
#  'kuhdz',
#  'goal_dallas',
#  'scott.collins@latimes.com',
#  'oly-2004-box',
#  'mayanist',
#  'www.caib.us',
#  'balzac',
#  '_____________________________________________',
#  'speculates',
#  'neuroscientist',
#  'self-described',
#  'dobrogeanu-gherea',
#  'nachmanides',
#  'talmudic',
#  'alchemists',
#  'jurisprudence',
#  'fascinated',
#  'hitchens',
#  'taymiyyah',
#  'librarian',
#  'oly-2004-gymnastics',
#  'likewise',
#  'kurtz',
#  'achebe',
#  'dickens',
#  'lg03',
#  'http://www.nobel.no',
#  'pawf',
#  'oly-2004-cycling',
#  'swordsman',
#  'nāgārjuna',
#  'homeopath',
#  'psychoanalysts',
#  '256-549-2091',
#  'wc2003-pak',
#  'dvaita',
#  'idiom',
#  'oculist',
#  'barrister',
#  '28aou94',
#  'goal_ottawa',
#  'geoffrey',
#  'lacan',
#  'stesichorus',
#  'tinkerer',
#  'hispanist',
#  'kalkbrenner',
#  'theodore',
#  'faxian',
#  '722-0192',
#  'al-jahiz',
#  'jean-paul',
#  'rabbi',
#  'goalies_pittsburgh',
#  'foundational',
#  'psychopath',
#  'russian/soviet',
#  'florus',
#  '20-hong',
#  'researcher',
#  'druggist',
#  'wc2003-sri',
#  'finkelstein',
#  'fourth-century',
#  'metalsmith',
#  'deconstruction',
#  'canyonres',
#  'batting_fthomas',
#  'bertram',
#  'poststructuralist',
#  'traditionalist',
#  'prankster',
#  'anarchism',
#  'coalminer',
#  'tutelage',
#  'evangelist',
#  'http://www.statoil.com',
#  'springer@globe.com',
#  'eulepidotis',
#  'connoisseur',
#  'perspective',
#  'richler',
#  'pyoot',
#  'son-in-law',
#  'herder',
#  'arachnologist',
#  'badiou',
#  'soothsayer',
#  'chansonnier',
#  'http://www.xerox.com',
#  'theocritus',
#  'auteur',
#  'jansenist',
#  'elder',
#  'flashaafp.com',
#  'nj04',
#  'mckibben',
#  'experimentalist',
#  'pediatrician',
#  'kma02',
#  'objectivism',
#  'testament',
#  'cryptanalyst',
#  'mythologist',
#  'sensualist',
#  'domingue',
#  'antisthenes',
#  'breslov',
#  'vahld',
#  'missiology',
#  'heretic',
#  'period_8',
#  'sophists',
#  'prof',
#  'http://www.genoa',
#  'hermocrates',
#  'indnsia',
#  'doubles_grudzielanek',
#  'jazzman',
#  '____________________________________________',
#  'http://www.asahi.com',
#  'berossus',
#  'minimalism',
#  'healer',
#  'rcw03',
#  'bases_rollins',
#  'german-born',
#  'linguistics',
#  'esperantist',
#  'personified',
#  'london-born',
#  'described',
#  'kuvempu',
#  'analogy',
#  '15utl',
#  'kroyts',
#  'mosaicist',
#  'strabo',
#  'frontiersman',
#  'rădulescu-motru',
#  '206-448-8004',
#  'schemer',
#  'entomologist',
#  'ss-hauptsturmführer',
#  'quebecer',
#  'goal_anaheim',
#  'anti-semite',
#  'con-artist',
#  'co02',
#  'kambar',
#  'discourse',
#  'palestinian-american',
#  'marcellinus',
#  'vitalism',
#  'minimalist',
#  'rashi',
#  'michelinie',
#  '+.56',
#  'betjeman',
#  'well-respected',
#  'sunmicro',
#  'clifford',
#  'marks/100kg',
#  'homiletics',
#  'textbook',
#  'tertullian',
#  'stendhal',
#  'vesalius',
#  'horticulturalist',
#  'hits_gwynn',
#  'samuel',
#  '27aou94',
#  'adherent',
#  'overachiever',
#  'germar',
#  'linguists',
#  'bb97',
#  'jesuit',
#  'apelles',
#  'emigre',
#  'hazrath',
#  'philosophes',
#  'personage',
#  'jongleur',
#  'philodemus',
#  'starets',
#  'folksinger',
#  'world-view',
#  'friend',
#  'colonel-general',
#  'tosafist',
#  'http://www.nsgtmo.navy.mil',
#  'gide',
#  'dv04',
#  'hypnotist',
#  '.0211',
#  'tvtonightnytsyn.com',
#  '3.7506',
#  'goals_none',
#  'rodin',
#  'workaholic',
#  'grandson',
#  'celan',
#  'nahmanides',
#  'iconoclastic',
#  'etymologist',
#  'scholasticism',
#  'charlatan',
#  'http://www.timewarner.com',
#  'newspapermen',
#  'opined',
#  'relates',
#  'wrldcom',
#  'positivism',
#  'japanologist',
#  'trouvère',
#  'oly-2004-weightlifting',
#  'ex-boxer',
#  'eyman@pbpost.com',
#  'manilius',
#  'michelet',
#  'archetype',
#  'paediatrician',
#  'slavist',
#  'lehf',
#  'marx',
#  'http://www.kasparovchess.com',
#  '.0210',
#  'egotist',
#  'rcw02',
#  'conceptualist',
#  'writer/editor',
#  'mp02',
#  'kd95',
#  'famed',
#  'characterizes',
#  'js04',
#  'karateka',
#  'oly-2004-basket',
#  '3-0-16-0',
#  'expressionist',
#  'laennec',
#  'pioneered',
#  'hellenist',
#  'goethe',
#  'ex-soldier',
#  'ihj',
#  '18th-century',
#  'nominalist',
#  'diarist',
#  'bryologist',
#  'karaite',
#  'ethnographers',
#  'peyrefitte',
#  'escoffier',
#  'brother-in-law',
#  'satirists',
#  'æthelweard',
#  'rohch',
#  'rbi_mramirez',
#  'triples_garciaparra',
#  'post-modernist',
#  'jeph',
#  'humanistic',
#  'jmccabe@globe.com',
#  '30-270',
#  'nennius',
#  'statesmen',
#  'a.k.a.',
#  'padmasambhava',
#  'hasid',
#  'http://www.comair.com',
#  'curmudgeon',
#  'alchemical',
#  'slovakrep',
#  'balthus',
#  'channelsurfer',
#  'gph02',
#  'eutropius',
#  'saves_hoffman',
#  'stein',
#  'necol.htm',
#  'palaeographer',
#  'studied',
#  'quintilian',
#  'gastronome',
#  'founders',
#  'avant-garde',
#  'actor/comedian',
#  ...]

# %%
find_closest_embeddings(embeddings_dict["philosopher"])[:5]
# Out:
# ['philosopher', 'mathematician', 'theologian', 'thinker', 'philosophers']

# %%
print(find_closest_embeddings(embeddings_dict["love"])[:20])
# Out:
# ['love', 'passion', 'dream', 'wonder', 'mind', 'true', 'life', 'dreams', 'always', 'loves', 'kind', 'friends', 'remember', 'loved', 'happy', 'forget', 'fun', 'wish', 'crazy', 'me']

# %%
print(find_closest_embeddings(embeddings_dict["love"] + embeddings_dict["life"])[:20])
# Out:
# ['love', 'life', 'my', 'her', 'she', 'you', '``', 'good', 'mother', 'i', 'like', 'man', 'me', 'mind', 'kind', 'lives', 'story', 'what', 'things', 'something']

# %%
print(find_closest_embeddings(embeddings_dict["love"] - embeddings_dict["hate"] + embeddings_dict["life"])[:20])
# Out:
# ['life', 'love', 'her', 'mother', 'she', 'father', 'man', 'great', 'dream', 'beauty', 'romantic', 'dreams', 'character', 'grace', 'story', 'lives', 'couple', 'his', 'journey', 'lover']

# %% [markdown]
# I appreciate how the code above returns words like 'mother' and 'father' as top results. This outcome is logically sound, as it aligns with the transformed context generated by subtracting 'hate' and adding 'life' to the word 'love' in the word embeddings.

# %%
print(find_closest_embeddings(embeddings_dict["human"] + embeddings_dict["peace"])[:20])
# Out:
# ['peace', 'human', 'democracy', 'rights', 'conflict', 'efforts', 'progress', 'reconciliation', 'process', 'unity', 'cooperation', 'our', 'dialogue', 'freedom', 'organization', 'hope', 'political', 'nations', 'peaceful', 'talks']

# %%
words =  list(embeddings_dict.keys())
vectors = [embeddings_dict[word] for word in words]
X = np.asarray(vectors)

# %%
import warnings
# Ignore the warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn.manifold._t_sne")

tsne = TSNE(n_components=2, random_state=0)
Y = tsne.fit_transform(X[:1000])
warnings.filterwarnings("default")

# %%
import warnings
# Ignore the warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn.manifold._t_sne")
tsne = TSNE(n_components=2, random_state=0)
words =  list(embeddings_dict.keys())
vectors = [embeddings_dict[word] for word in words]
Y = tsne.fit_transform(vectors[:1000])
plt.scatter(Y[:, 0], Y[:, 1])

for label, x, y in zip(words, Y[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords="offset points")
plt.show()
warnings.filterwarnings("default")

# %%
import warnings
# Ignore the warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn.manifold._t_sne")

tsne = TSNE(n_components=2, random_state=0, perplexity=30, learning_rate=200.0)
words =  list(embeddings_dict.keys())
vectors = [embeddings_dict[word] for word in words]
Y = tsne.fit_transform(vectors[:250])
plt.scatter(Y[:, 0], Y[:, 1])

for label, x, y in zip(words, Y[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords="offset points")
plt.show()
warnings.filterwarnings("default")

# %%
import warnings
# Ignore the warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn.manifold._t_sne")

tsne = TSNE(n_components=2, random_state=0, perplexity=30, learning_rate=200.0)
words =  list(embeddings_dict.keys())
vectors = [embeddings_dict[word] for word in words]
Y = tsne.fit_transform(vectors[:100])
plt.scatter(Y[:, 0], Y[:, 1])

for label, x, y in zip(words, Y[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords="offset points")
plt.show()
warnings.filterwarnings("default")

# %%
import warnings
# Ignore the warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn.manifold._t_sne")

tsne = TSNE(n_components=2, random_state=0, perplexity=30, learning_rate=200.0)
words =  list(embeddings_dict.keys())
vectors = [embeddings_dict[word] for word in words]
Y = tsne.fit_transform(vectors[:80])
plt.scatter(Y[:, 0], Y[:, 1])

for label, x, y in zip(words, Y[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords="offset points")
plt.show()
warnings.filterwarnings("default")

# %% [markdown]
# When I first looked for words most similar to "love" in the book "Sophie's World" using the Gensim model, the results were a bit surprising. It gave words like "moon," "contain," "marx," and "eggs," which don't seem immediately connected to "love."
#
# In contrast, when I used the GloVe model to search for "love," the results were much more intuitive. It provided words like "passion," "dream," "true," "life," and "friends," which are words that we naturally associate with the concept of "love."
